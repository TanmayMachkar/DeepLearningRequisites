# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# "manually" in numpy

z = [1, 2, 3]

# compute softmax result
num = np.exp(z)
den = np.sum(np.exp(z))
sigma = num/den
print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(-5, high = 15, size = 25)
print(z)

# compute softmax result
num = np.exp(z)
den = np.sum(np.exp(z))
sigma = num/den

# compare
plt.plot(z, sigma, "ko")
plt.xlabel("Original number (z)")
plt.ylabel("Softmaxified $\sigma$")
plt.yscale("log")
plt.title("$\sum\sigma$ = %g" %np.sum(sigma))
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4720\2075530834.py:13: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("Softmaxified $\sigma$")
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4720\2075530834.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("$\sum\sigma$ = %g" %np.sum(sigma))
# [ 3  7 -1 -2 14 12 -5 -5  2  1  8 -3  8  3  0 13  7 -4 10  6  8 -5 10  2
#  -1]

# %%
## Using pytorch

# create an instance of the softmax activation class
softfun = nn.Softmax(dim = 0)

# then apply the data to that function
sigmaT = softfun(torch.Tensor(z))

print(sigmaT)
# Out:
# tensor([1.0779e-05, 5.8850e-04, 1.9742e-07, 7.2627e-08, 6.4537e-01, 8.7342e-02,
#         3.6159e-09, 3.6159e-09, 3.9653e-06, 1.4588e-06, 1.5997e-03, 2.6718e-08,
#         1.5997e-03, 1.0779e-05, 5.3665e-07, 2.3742e-01, 5.8850e-04, 9.8290e-09,
#         1.1820e-02, 2.1650e-04, 1.5997e-03, 3.6159e-09, 1.1820e-02, 3.9653e-06,
#         1.9742e-07])

# %%
plt.plot(sigma, sigmaT, "ko")
plt.xlabel('"Manual" softmax')
plt.ylabel("Pytorch nn.Softmax")
plt.title(f"The two methods correlate at r = {np.corrcoef(sigma, sigmaT)[0, 1]}")
# np.corroeff blah blah returns 2x2 matrix where at [0, 1] position we can find the r value
plt.show()
